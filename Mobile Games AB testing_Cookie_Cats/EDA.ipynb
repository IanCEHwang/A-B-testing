# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### View data set

# %% [markdown]
# - `userid` - a unique number that identifies each player.
# - `version` - whether the player was put in the control group (gate_30 - a gate at level 30) or the test group (gate_40 - a gate at level 40).
# - `sum_gamerounds` - the number of game rounds played by the player during the first week after installation
# - `retention_1` - did the player come back and play 1 day after installing?
# - `retention_7` - did the player come back and play 7 days after installing?

# %%
df = pd.read_csv("data_source/cookie_cats.csv")
df.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3        False        False
# 1     337  gate_30              38         True        False
# 2     377  gate_40             165         True        False
# 3     483  gate_40               1        False        False
# 4     488  gate_40             179         True         True

# %% [markdown]
# ### EDA

# %% [markdown]
# >**Check for Null values**

# %%
df.isnull().count()
# Out:
# userid            90189
# version           90189
# sum_gamerounds    90189
# retention_1       90189
# retention_7       90189
# dtype: int64

# %% [markdown]
# >**Distribution of number of rounds played**

# %%
plt.subplot(1 , 3 , 1)
df.groupby('sum_gamerounds').size().plot.box()

plt.subplot(1 , 3 , 2)
df.groupby('sum_gamerounds').size().plot.hist(width = 100)

plt.subplot(1 , 3 , 3)
df.groupby('sum_gamerounds').size().plot.hist(cumulative=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.groupby('sum_gamerounds').size().plot.box()
# Out:
# <AxesSubplot: >

# %%
df.groupby('sum_gamerounds').size().plot.hist(width = 100)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.groupby('sum_gamerounds').size().plot.hist(cumulative=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Most of the data points scattered within 1000, plot again with smaller scale

# %%
df.groupby('sum_gamerounds').size().iloc[:100].plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# >**Version**

# %%
df.groupby('version').size().plot.pie(autopct='%.1f%%')
# Out:
# <AxesSubplot: >

# %% [markdown]
# test and control group sizes are roughly the same

# %% [markdown]
# >**Come back and play in 1 day**

# %%
df[df['version'] == 'gate_30'].groupby(['retention_1']).size().plot.pie(autopct='%.1f%%' , title = 'Gate 30')
# Out:
# <AxesSubplot: title={'center': 'Gate 30'}>

# %%
df[df['version'] == 'gate_40'].groupby(['retention_1']).size().plot.pie(autopct='%.1f%%' , title = 'Gate 40')
# Out:
# <AxesSubplot: title={'center': 'Gate 40'}>

# %% [markdown]
# >**Come back and play in 7 days**

# %%
df[df['version'] == 'gate_30'].groupby(['retention_7']).size().plot.pie(autopct='%.1f%%' , title = 'Gate 30')
# Out:
# <AxesSubplot: title={'center': 'Gate 30'}>

# %%
df[df['version'] == 'gate_40'].groupby(['retention_7']).size().plot.pie(autopct='%.1f%%' , title = 'Gate 40')
# Out:
# <AxesSubplot: title={'center': 'Gate 40'}>
